# %%
import numpy as np

# %%
array_1 = np.array([2,4,7,2,8,8,9]) #create an array of n values
array_2 = np.random.randint (0,10,7) #create an array random int values

print(array_1, array_2) #print
print(array_1.shape, array_2.shape)
print(array_1 + array_2) #
print(np.dot(array_1, array_2))
# Out:
# [2 4 7 2 8 8 9] [1 7 0 8 3 7 1]
# (7,) (7,)
# [ 3 11  7 10 11 15 10]
# 135

# %%
array_1[3] = 70
print(array_1)
# Out:
# [ 2  4  7 70  8  8  9]

# %%
array_3 = array_1 * array_2
print(array_3)
# Out:
# [  2  28   0 560  24  56   9]

# %%
#Open cv

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/content/lena.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

print(img.shape)
# Out:
# (300, 400, 3)

# %%
print(img[0:10, 0:5, 0], type(img), img.dtype) # el cero es le canal de color
# Out:
# [[  0  21  15   7   0]
#  [ 18  91 102 106  95]
#  [ 15 107 122 114 104]
#  [  5 104 114 100  93]
#  [  0  88 104 104 103]
#  [ 11 107 120 124 127]
#  [ 12 110 116 110 113]
#  [  0 103 113 104 105]
#  [  0 118 120 103 113]
#  [  0 118 120 103 113]] <class 'numpy.ndarray'> uint8

# %%
img = cv2.imread("/content/lena.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img[0:50, 0:50, 0:1] = 0
print(img[0:51, 0:51,1])
plt.imshow(img)
# Out:
# [[  6  10   0 ...   0   0   0]
#  [  8  49  48 ... 102 102 102]
#  [  0  54  56 ... 103 103 103]
#  ...
#  [  2  89  98 ...  66  50  41]
#  [  3  91 100 ...  56  45  37]
#  [  4  92 100 ...  47  39  36]]

# %%
lena_face = img[100:200, 170:260, :]# : todos los canales de color

# %%
plt.imshow(lena_face)

print(img.shape)
# Out:
# (300, 400, 3)

# %%
img_gray = cv2.imread("/content/lena.jpg", 0)  # el cero poner la imagen en escala de grises
#img_gray = cv2.cvtColor(img_gray, cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray, cmap='gray') #cmap='gray' cambia a gris
print(img_gray.shape)
# Out:
# (300, 400)
